# %%
# %matplotlib inline  

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import numpy as np

# %%
# Veriyi karıştırıp Eğitim ve Test olarak ayıralım
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train/=255
X_test/=255

# %% [markdown]
# # ORJİNAL

# %%
datagen = ImageDataGenerator()
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # DÖNDÜRME

# %%
datagen = ImageDataGenerator(rotation_range=359)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # YATAY KAYDIRMA

# %%
datagen = ImageDataGenerator(width_shift_range=0.5)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # DİKEY KAYDIRMA

# %%
datagen = ImageDataGenerator(height_shift_range=0.5)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # YAKINLAŞTIRMA

# %%
datagen = ImageDataGenerator(zoom_range=0.3)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # YATAY SİMETRİĞİNİ ALMA

# %%
datagen = ImageDataGenerator(horizontal_flip=True)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %% [markdown]
# # DİKEY SİMETRİĞİNİ ALMA

# %%
datagen = ImageDataGenerator(vertical_flip=True)
datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=4, seed=499):
    for i in range(0, 4): 
        plt.subplot(220 + 1 + i) 
        plt.imshow(X_batch[i])
    plt.show() 
    break

# %%
##Dikey ve yatay kaydırma orjinal koda göre ters çalıştı ??
